# %%
from config import API_KEY
import pandas as pd
import plotly.express as px

# %%
# Data Collection
from tiingo import TiingoClient
from datetime import datetime, timedelta

config = {
    'api_key': API_KEY,
    'session': True  # Use requests.Session
}
client = TiingoClient(config)

# Calculate the start date as today's date minus 2 years
end_date = datetime.now()
start_date = end_date - timedelta(days=20*365)

# Convert dates to string format
start_date_str = start_date.strftime('%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')

df = client.get_dataframe('TSLA', frequency='daily',startDate=start_date_str, endDate=end_date_str)

# %%
df.head()
# Out:
#                            close     high    low   open    volume  adjClose  \
# date
# 2010-06-29 00:00:00+00:00  23.89  25.0000  17.54  19.00  18766300  1.592667
# 2010-06-30 00:00:00+00:00  23.83  30.4192  23.30  25.79  17187100  1.588667
# 2010-07-01 00:00:00+00:00  21.96  25.9200  20.27  25.00   8218800  1.464000
# 2010-07-02 00:00:00+00:00  19.20  23.1000  18.71  23.00   5139800  1.280000
# 2010-07-06 00:00:00+00:00  16.11  20.0000  15.83  20.00   6866900  1.074000
#
#                             adjHigh    adjLow   adjOpen  adjVolume  divCash  \
# date
# 2010-06-29 00:00:00+00:00  1.666667  1.169333  1.266667  281494500      0.0
# 2010-06-30 00:00:00+00:00  2.027947  1.553333  1.719333  257806500      0.0
# 2010-07-01 00:00:00+00:00  1.728000  1.351333  1.666667  123282000      0.0
# 2010-07-02 00:00:00+00:00  1.540000  1.247333  1.533333   77097000      0.0
# 2010-07-06 00:00:00+00:00  1.333333  1.055333  1.333333  103003500      0.0
#
#                            splitFactor
# date
# 2010-06-29 00:00:00+00:00          1.0
# 2010-06-30 00:00:00+00:00          1.0
# 2010-07-01 00:00:00+00:00          1.0
# 2010-07-02 00:00:00+00:00          1.0
# 2010-07-06 00:00:00+00:00          1.0

# %%
df.reset_index(inplace=True)
df.rename(columns={'index': 'new_index'}, inplace=True)  # Rename the old index column
df['date'] = df['date'].dt.date  # Extract the date part from the datetime index
df
# Out:
#             date   close      high       low    open     volume    adjClose  \
# 0     2010-06-29   23.89   25.0000   17.5400   19.00   18766300    1.592667
# 1     2010-06-30   23.83   30.4192   23.3000   25.79   17187100    1.588667
# 2     2010-07-01   21.96   25.9200   20.2700   25.00    8218800    1.464000
# 3     2010-07-02   19.20   23.1000   18.7100   23.00    5139800    1.280000
# 4     2010-07-06   16.11   20.0000   15.8300   20.00    6866900    1.074000
# ...          ...     ...       ...       ...     ...        ...         ...
# 3428  2024-02-12  188.13  194.7300  187.2800  192.11   95498597  188.130000
# 3429  2024-02-13  184.02  187.2600  182.1087  183.99   86759478  184.020000
# 3430  2024-02-14  188.71  188.8900  183.3500  185.30   81202987  188.710000
# 3431  2024-02-15  200.45  200.8800  188.8595  189.16  120831762  200.450000
# 3432  2024-02-16  199.95  203.1700  197.4000  202.06  111346705  199.950000
#
#          adjHigh      adjLow     adjOpen  adjVolume  divCash  splitFactor
# 0       1.666667    1.169333    1.266667  281494500      0.0          1.0
# 1       2.027947    1.553333    1.719333  257806500      0.0          1.0
# 2       1.728000    1.351333    1.666667  123282000      0.0          1.0
# 3       1.540000    1.247333    1.533333   77097000      0.0          1.0
# 4       1.333333    1.055333    1.333333  103003500      0.0          1.0
# ...          ...         ...         ...        ...      ...          ...
# 3428  194.730000  187.280000  192.110000   95498597      0.0          1.0
# 3429  187.260000  182.108700  183.990000   86759478      0.0          1.0
# 3430  188.890000  183.350000  185.300000   81202987      0.0          1.0
# 3431  200.880000  188.859500  189.160000  120831762      0.0          1.0
# 3432  203.170000  197.400000  202.060000  111346705      0.0          1.0
#
# [3433 rows x 13 columns]

# %%
# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# %%
#  extract month and year from dates
df['Month'] = [i.month for i in df['date']]
df['Year'] = [i.year for i in df['date']]
df['Day'] = [i.day for i in df['date']]

# %%
import numpy as np 
# # create a sequence of numbers
# df['Series'] = np.arange(1,len(df)+1)

# %%
df.drop(['volume','close','high','low','open','adjVolume','divCash'],axis=1,inplace=True)
df = df[['Year','Month','Day','adjClose','adjHigh','adjLow','adjOpen','date']]
df.head()
# Out:
#    Year  Month  Day  adjClose   adjHigh    adjLow   adjOpen       date
# 0  2010      6   29  1.592667  1.666667  1.169333  1.266667 2010-06-29
# 1  2010      6   30  1.588667  2.027947  1.553333  1.719333 2010-06-30
# 2  2010      7    1  1.464000  1.728000  1.351333  1.666667 2010-07-01
# 3  2010      7    2  1.280000  1.540000  1.247333  1.533333 2010-07-02
# 4  2010      7    6  1.074000  1.333333  1.055333  1.333333 2010-07-06

# %%
df.head()
# Out:
#    Year  Month  Day  adjClose   adjHigh    adjLow   adjOpen       date
# 0  2010      6   29  1.592667  1.666667  1.169333  1.266667 2010-06-29
# 1  2010      6   30  1.588667  2.027947  1.553333  1.719333 2010-06-30
# 2  2010      7    1  1.464000  1.728000  1.351333  1.666667 2010-07-01
# 3  2010      7    2  1.280000  1.540000  1.247333  1.533333 2010-07-02
# 4  2010      7    6  1.074000  1.333333  1.055333  1.333333 2010-07-06

# %%
# Drop the first row since it doesn't have a previous day's closing price to compare with
df = df.dropna()

# %%
df_copy = df.copy()
df_copy
# Out:
#       Year  Month  Day    adjClose     adjHigh      adjLow     adjOpen  \
# 0     2010      6   29    1.592667    1.666667    1.169333    1.266667
# 1     2010      6   30    1.588667    2.027947    1.553333    1.719333
# 2     2010      7    1    1.464000    1.728000    1.351333    1.666667
# 3     2010      7    2    1.280000    1.540000    1.247333    1.533333
# 4     2010      7    6    1.074000    1.333333    1.055333    1.333333
# ...    ...    ...  ...         ...         ...         ...         ...
# 3428  2024      2   12  188.130000  194.730000  187.280000  192.110000
# 3429  2024      2   13  184.020000  187.260000  182.108700  183.990000
# 3430  2024      2   14  188.710000  188.890000  183.350000  185.300000
# 3431  2024      2   15  200.450000  200.880000  188.859500  189.160000
# 3432  2024      2   16  199.950000  203.170000  197.400000  202.060000
#
#            date
# 0    2010-06-29
# 1    2010-06-30
# 2    2010-07-01
# 3    2010-07-02
# 4    2010-07-06
# ...         ...
# 3428 2024-02-12
# 3429 2024-02-13
# 3430 2024-02-14
# 3431 2024-02-15
# 3432 2024-02-16
#
# [3433 rows x 8 columns]

# %%
df.drop(['date'],axis=1,inplace=True)

# %%
df_copy.head()
# Out:
#    Year  Month  Day  adjClose   adjHigh    adjLow   adjOpen       date
# 0  2010      6   29  1.592667  1.666667  1.169333  1.266667 2010-06-29
# 1  2010      6   30  1.588667  2.027947  1.553333  1.719333 2010-06-30
# 2  2010      7    1  1.464000  1.728000  1.351333  1.666667 2010-07-01
# 3  2010      7    2  1.280000  1.540000  1.247333  1.533333 2010-07-02
# 4  2010      7    6  1.074000  1.333333  1.055333  1.333333 2010-07-06

# %%
# Split Train Test into 80/20 ratio

pos=int(round(len(df)*(0.8)))
train=df[:pos]
test=df[pos:]
train.shape, test.shape
# int(round(len(df)*(1-0.2)))
# Out:
# ((2746, 7), (687, 7))

# %%
# split data into train-test set
# train = df[df['Year'] < 2023]
# test = df[df['Year'] >= 2023]
# check shape

# %%
# Setup the classification task with time series configuration
# import the regression module
from pycaret.regression import *
# initialize setup
close_s = setup(data=train, test_data=test, target='adjClose', fold_strategy='timeseries', numeric_features=['Year'], data_split_shuffle=False, fold_shuffle=False, session_id=123)

# import pycaret classification and init setup
# from pycaret.time_series import *
# close_s=setup(data=train,target='adjClose',fh = 7, fold = 3, seasonal_period = 5, session_id = 123)
# Out:
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\utils\validation\series.py:21: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\forecasting\base\_fh.py:18: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   RELATIVE_TYPES = (pd.Int64Index, pd.RangeIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\forecasting\base\_fh.py:19: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   ABSOLUTE_TYPES = (pd.Int64Index, pd.RangeIndex, pd.DatetimeIndex, pd.PeriodIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\datatypes\_series\_check.py:43: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\datatypes\_hierarchical\_check.py:50: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\datatypes\_hierarchical\_check.py:51: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_MULTIINDEX_TYPES = (pd.Int64Index, pd.RangeIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\datatypes\_panel\_check.py:48: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\sktime\datatypes\_panel\_check.py:49: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_MULTIINDEX_TYPES = (pd.Int64Index, pd.RangeIndex)
# <style type="text/css">
# #T_7198d_row7_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7198d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7198d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7198d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7198d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7198d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7198d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7198d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7198d_row1_col1" class="data row1 col1" >adjClose</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7198d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7198d_row2_col1" class="data row2 col1" >regression</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7198d_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_7198d_row3_col1" class="data row3 col1" >(3433, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7198d_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_7198d_row4_col1" class="data row4 col1" >(3433, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7198d_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_7198d_row5_col1" class="data row5 col1" >(687, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7198d_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_7198d_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7198d_row7_col0" class="data row7 col0" >Preprocess</td>
#       <td id="T_7198d_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7198d_row8_col0" class="data row8 col0" >Imputation type</td>
#       <td id="T_7198d_row8_col1" class="data row8 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7198d_row9_col0" class="data row9 col0" >Numeric imputation</td>
#       <td id="T_7198d_row9_col1" class="data row9 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7198d_row10_col0" class="data row10 col0" >Categorical imputation</td>
#       <td id="T_7198d_row10_col1" class="data row10 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7198d_row11_col0" class="data row11 col0" >Fold Generator</td>
#       <td id="T_7198d_row11_col1" class="data row11 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7198d_row12_col0" class="data row12 col0" >Fold Number</td>
#       <td id="T_7198d_row12_col1" class="data row12 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7198d_row13_col0" class="data row13 col0" >CPU Jobs</td>
#       <td id="T_7198d_row13_col1" class="data row13 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7198d_row14_col0" class="data row14 col0" >Log Experiment</td>
#       <td id="T_7198d_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7198d_row15_col0" class="data row15 col0" >Experiment Name</td>
#       <td id="T_7198d_row15_col1" class="data row15 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7198d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7198d_row16_col0" class="data row16 col0" >USI</td>
#       <td id="T_7198d_row16_col1" class="data row16 col1" >ff42</td>
#     </tr>
#   </tbody>
# </table>

# %%
close_best = compare_models(sort = 'MAE')
# Out:
# <style type="text/css">
# #T_21c16 th {
#   text-align: left;
# }
# #T_21c16_row0_col0, #T_21c16_row0_col3, #T_21c16_row0_col4, #T_21c16_row0_col5, #T_21c16_row0_col6, #T_21c16_row1_col0, #T_21c16_row1_col1, #T_21c16_row1_col2, #T_21c16_row1_col3, #T_21c16_row1_col5, #T_21c16_row2_col0, #T_21c16_row2_col1, #T_21c16_row2_col2, #T_21c16_row2_col6, #T_21c16_row3_col0, #T_21c16_row3_col1, #T_21c16_row3_col2, #T_21c16_row3_col6, #T_21c16_row4_col0, #T_21c16_row4_col1, #T_21c16_row4_col2, #T_21c16_row4_col3, #T_21c16_row4_col4, #T_21c16_row4_col5, #T_21c16_row4_col6, #T_21c16_row5_col0, #T_21c16_row5_col1, #T_21c16_row5_col2, #T_21c16_row5_col3, #T_21c16_row5_col4, #T_21c16_row5_col5, #T_21c16_row5_col6, #T_21c16_row6_col0, #T_21c16_row6_col1, #T_21c16_row6_col2, #T_21c16_row6_col3, #T_21c16_row6_col4, #T_21c16_row6_col5, #T_21c16_row6_col6, #T_21c16_row7_col0, #T_21c16_row7_col1, #T_21c16_row7_col2, #T_21c16_row7_col3, #T_21c16_row7_col4, #T_21c16_row7_col5, #T_21c16_row7_col6, #T_21c16_row8_col0, #T_21c16_row8_col1, #T_21c16_row8_col2, #T_21c16_row8_col3, #T_21c16_row8_col4, #T_21c16_row8_col5, #T_21c16_row8_col6, #T_21c16_row9_col0, #T_21c16_row9_col1, #T_21c16_row9_col2, #T_21c16_row9_col3, #T_21c16_row9_col4, #T_21c16_row9_col5, #T_21c16_row9_col6, #T_21c16_row10_col0, #T_21c16_row10_col1, #T_21c16_row10_col2, #T_21c16_row10_col3, #T_21c16_row10_col4, #T_21c16_row10_col5, #T_21c16_row10_col6, #T_21c16_row11_col0, #T_21c16_row11_col1, #T_21c16_row11_col2, #T_21c16_row11_col3, #T_21c16_row11_col4, #T_21c16_row11_col5, #T_21c16_row11_col6, #T_21c16_row12_col0, #T_21c16_row12_col1, #T_21c16_row12_col2, #T_21c16_row12_col3, #T_21c16_row12_col4, #T_21c16_row12_col5, #T_21c16_row12_col6, #T_21c16_row13_col0, #T_21c16_row13_col1, #T_21c16_row13_col2, #T_21c16_row13_col3, #T_21c16_row13_col4, #T_21c16_row13_col5, #T_21c16_row13_col6, #T_21c16_row14_col0, #T_21c16_row14_col1, #T_21c16_row14_col2, #T_21c16_row14_col3, #T_21c16_row14_col4, #T_21c16_row14_col5, #T_21c16_row14_col6, #T_21c16_row15_col0, #T_21c16_row15_col1, #T_21c16_row15_col2, #T_21c16_row15_col3, #T_21c16_row15_col4, #T_21c16_row15_col5, #T_21c16_row15_col6, #T_21c16_row16_col0, #T_21c16_row16_col1, #T_21c16_row16_col2, #T_21c16_row16_col3, #T_21c16_row16_col4, #T_21c16_row16_col5, #T_21c16_row16_col6, #T_21c16_row17_col0, #T_21c16_row17_col1, #T_21c16_row17_col2, #T_21c16_row17_col3, #T_21c16_row17_col4, #T_21c16_row17_col5, #T_21c16_row17_col6, #T_21c16_row18_col0, #T_21c16_row18_col1, #T_21c16_row18_col2, #T_21c16_row18_col3, #T_21c16_row18_col4, #T_21c16_row18_col5, #T_21c16_row18_col6, #T_21c16_row19_col0, #T_21c16_row19_col1, #T_21c16_row19_col2, #T_21c16_row19_col3, #T_21c16_row19_col4, #T_21c16_row19_col5, #T_21c16_row19_col6 {
#   text-align: left;
# }
# #T_21c16_row0_col1, #T_21c16_row0_col2, #T_21c16_row1_col4, #T_21c16_row1_col6, #T_21c16_row2_col3, #T_21c16_row2_col4, #T_21c16_row2_col5, #T_21c16_row3_col3, #T_21c16_row3_col4, #T_21c16_row3_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_21c16_row0_col7, #T_21c16_row1_col7, #T_21c16_row2_col7, #T_21c16_row4_col7, #T_21c16_row6_col7, #T_21c16_row7_col7, #T_21c16_row8_col7, #T_21c16_row9_col7, #T_21c16_row10_col7, #T_21c16_row11_col7, #T_21c16_row12_col7, #T_21c16_row13_col7, #T_21c16_row14_col7, #T_21c16_row15_col7, #T_21c16_row16_col7, #T_21c16_row17_col7, #T_21c16_row18_col7, #T_21c16_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_21c16_row3_col7, #T_21c16_row5_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_21c16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21c16_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_21c16_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_21c16_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_21c16_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_21c16_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_21c16_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_21c16_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_21c16_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21c16_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_21c16_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_21c16_row0_col1" class="data row0 col1" >0.8074</td>
#       <td id="T_21c16_row0_col2" class="data row0 col2" >3.2574</td>
#       <td id="T_21c16_row0_col3" class="data row0 col3" >1.0882</td>
#       <td id="T_21c16_row0_col4" class="data row0 col4" >0.9911</td>
#       <td id="T_21c16_row0_col5" class="data row0 col5" >0.0122</td>
#       <td id="T_21c16_row0_col6" class="data row0 col6" >0.0099</td>
#       <td id="T_21c16_row0_col7" class="data row0 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_21c16_level0_row1" class="row_heading level0 row1" >lar</th>
#       <td id="T_21c16_row1_col0" class="data row1 col0" >Least Angle Regression</td>
#       <td id="T_21c16_row1_col1" class="data row1 col1" >0.8121</td>
#       <td id="T_21c16_row1_col2" class="data row1 col2" >3.3353</td>
#       <td id="T_21c16_row1_col3" class="data row1 col3" >1.0826</td>
#       <td id="T_21c16_row1_col4" class="data row1 col4" >0.9938</td>
#       <td id="T_21c16_row1_col5" class="data row1 col5" >0.0109</td>
#       <td id="T_21c16_row1_col6" class="data row1 col6" >0.0088</td>
#       <td id="T_21c16_row1_col7" class="data row1 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_21c16_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_21c16_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_21c16_row2_col1" class="data row2 col1" >0.8124</td>
#       <td id="T_21c16_row2_col2" class="data row2 col2" >3.3335</td>
#       <td id="T_21c16_row2_col3" class="data row2 col3" >1.0811</td>
#       <td id="T_21c16_row2_col4" class="data row2 col4" >0.9938</td>
#       <td id="T_21c16_row2_col5" class="data row2 col5" >0.0108</td>
#       <td id="T_21c16_row2_col6" class="data row2 col6" >0.0089</td>
#       <td id="T_21c16_row2_col7" class="data row2 col7" >0.4080</td>
#     </tr>
#     <tr>
#       <th id="T_21c16_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_21c16_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_21c16_row3_col1" class="data row3 col1" >0.8126</td>
#       <td id="T_21c16_row3_col2" class="data row3 col2" >3.3338</td>
#       <td id="T_21c16_row3_col3" class="data row3 col3" >1.0811</td>
#       <td id="T_21c16_row3_col4" class="data row3 col4" >0.9938</td>
#       <td id="T_21c16_row3_col5" class="data row3 col5" >0.0108</td>
#       <td id="T_21c16_row3_col6" class="data row3 col6" >0.0089</td>
#       <td id="T_21c16_row3_col7" class="data row3 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_21c16_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_21c16_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_21c16_row4_col1" class="data row4 col1" >0.8181</td>
#       <td id="T_21c16_row4_col2" class="data row4 col2" >3.3360</td>
#       <td id="T_21c16_row4_col3" class="data row4 col3" >1.0892</td>
#       <td id="T_21c16_row4_col4" class="data row4 col4" >0.9917</td>
#       <td id="T_21c16_row4_col5" class="data row4 col5" >0.0119</td>
#       <td id="T_21c16_row4_col6" class="data row4 col6" >0.0098</td>
#       <td id="T_21c16_row4_col7" class="data row4 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_21c16_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_21c16_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_21c16_row5_col1" class="data row5 col1" >1.2653</td>
#       <td id="T_21c16_row5_col2" class="data row5 col2" >8.5838</td>
#       <td id="T_21c16_row5_col3" class="data row5 col3" >1.7525</td>
#       <td id="T_21c16

# %% [markdown]
# Analyze Model

# %%
evaluate_model(close_best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
prediction_holdout = predict_model(close_best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c856b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c856b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c856b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c856b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c856b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c856b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c856b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c856b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c856b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c856b_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_c856b_row0_col1" class="data row0 col1" >2.4399</td>
#       <td id="T_c856b_row0_col2" class="data row0 col2" >10.9890</td>
#       <td id="T_c856b_row0_col3" class="data row0 col3" >3.3150</td>
#       <td id="T_c856b_row0_col4" class="data row0 col4" >0.9967</td>
#       <td id="T_c856b_row0_col5" class="data row0 col5" >0.0127</td>
#       <td id="T_c856b_row0_col6" class="data row0 col6" >0.0098</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Prediction

# %%
# generate predictions on the original dataset
# predictions = predict_model(close_best)
predictions = predict_model(close_best, data=df)

# %%
predictions
# Out:
#       Year  Month  Day     adjHigh      adjLow     adjOpen       Label
# 0     2010      6   29    1.666667    1.169333    1.266667    1.539285
# 1     2010      6   30    2.027947    1.553333    1.719333    1.850269
# 2     2010      7    1    1.728000    1.351333    1.666667    1.460377
# 3     2010      7    2    1.540000    1.247333    1.533333    1.301961
# 4     2010      7    6    1.333333    1.055333    1.333333    1.100659
# ...    ...    ...  ...         ...         ...         ...         ...
# 3428  2024      2   12  194.730000  187.280000  192.110000  190.405987
# 3429  2024      2   13  187.260000  182.108700  183.990000  185.383184
# 3430  2024      2   14  188.890000  183.350000  185.300000  186.924276
# 3431  2024      2   15  200.880000  188.859500  189.160000  199.553430
# 3432  2024      2   16  203.170000  197.400000  202.060000  199.132245
#
# [3433 rows x 7 columns]

# %%
predictions['date'] = df_copy['date']

# %%
predictions
# Out:
#       Year  Month  Day     adjHigh      adjLow     adjOpen       Label  \
# 0     2010      6   29    1.666667    1.169333    1.266667    1.539285
# 1     2010      6   30    2.027947    1.553333    1.719333    1.850269
# 2     2010      7    1    1.728000    1.351333    1.666667    1.460377
# 3     2010      7    2    1.540000    1.247333    1.533333    1.301961
# 4     2010      7    6    1.333333    1.055333    1.333333    1.100659
# ...    ...    ...  ...         ...         ...         ...         ...
# 3428  2024      2   12  194.730000  187.280000  192.110000  190.405987
# 3429  2024      2   13  187.260000  182.108700  183.990000  185.383184
# 3430  2024      2   14  188.890000  183.350000  185.300000  186.924276
# 3431  2024      2   15  200.880000  188.859500  189.160000  199.553430
# 3432  2024      2   16  203.170000  197.400000  202.060000  199.132245
#
#            date
# 0    2010-06-29
# 1    2010-06-30
# 2    2010-07-01
# 3    2010-07-02
# 4    2010-07-06
# ...         ...
# 3428 2024-02-12
# 3429 2024-02-13
# 3430 2024-02-14
# 3431 2024-02-15
# 3432 2024-02-16
#
# [3433 rows x 8 columns]

# %%
predictions
# Out:
#       Year  Month  Day     adjHigh      adjLow     adjOpen       Label  \
# 0     2010      6   29    1.666667    1.169333    1.266667    1.539285
# 1     2010      6   30    2.027947    1.553333    1.719333    1.850269
# 2     2010      7    1    1.728000    1.351333    1.666667    1.460377
# 3     2010      7    2    1.540000    1.247333    1.533333    1.301961
# 4     2010      7    6    1.333333    1.055333    1.333333    1.100659
# ...    ...    ...  ...         ...         ...         ...         ...
# 3428  2024      2   12  194.730000  187.280000  192.110000  190.405987
# 3429  2024      2   13  187.260000  182.108700  183.990000  185.383184
# 3430  2024      2   14  188.890000  183.350000  185.300000  186.924276
# 3431  2024      2   15  200.880000  188.859500  189.160000  199.553430
# 3432  2024      2   16  203.170000  197.400000  202.060000  199.132245
#
#            date
# 0    2010-06-29
# 1    2010-06-30
# 2    2010-07-01
# 3    2010-07-02
# 4    2010-07-06
# ...         ...
# 3428 2024-02-12
# 3429 2024-02-13
# 3430 2024-02-14
# 3431 2024-02-15
# 3432 2024-02-16
#
# [3433 rows x 8 columns]

# %%
#  Line plot
fig = px.line(predictions, x='date', y=["adjOpen","Label"], template='plotly_dark')

# Add a vertical rectangle for test-set separation
fig.add_vrect(x0="2023-01-01", x1="2024-31-01", fillcolor="grey", opacity=0.25, line_width=0)

# Show the plot
fig.show()

# %%
final_best = finalize_model(close_best)
final_best
# Out:
# HuberRegressor()

# %%
# # Create a future scoring dataset

future_dates = pd.date_range(start='2024-02-17', end='2024-03-17', freq='B')

# Create a DataFrame for future dates
future_df = pd.DataFrame({
    'date': future_dates,
    'Series': np.arange(7548, 7548 + len(future_dates)),  # Assuming you want to continue the series numbering
    'Year': [d.year for d in future_dates],
    'Month': [d.month for d in future_dates],
    'Day': [d.day for d in future_dates],
    
    
    
    
})

future_df.head()
# Out:
#         date  Series  Year  Month  Day
# 0 2024-02-19    7548  2024      2   19
# 1 2024-02-20    7549  2024      2   20
# 2 2024-02-21    7550  2024      2   21
# 3 2024-02-22    7551  2024      2   22
# 4 2024-02-23    7552  2024      2   23

# %%
# #  Get the last date in your original DataFrame
# last_date = df_copy['date'].max()

# # Generate future dates starting from the next day after the last date
# future_dates = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=365, freq='D')

# # Create a DataFrame with the future dates
# future_df = pd.DataFrame({'date': future_dates})

# # Add other columns to the future DataFrame if needed
# future_df['Year'] = future_df['date'].dt.year
# future_df['Month'] = future_df['date'].dt.month
# future_df['Day'] = future_df['date'].dt.day
# future_df

# %%
predictions_future = predict_model(final_best, data=future_df)
predictions_future
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 predictions_future = predict_model(final_best, data=future_df)
#       2 predictions_future
#
# File c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\pycaret\regression\functional.py:1763, in predict_model(estimator, data, drift_report, round, verbose)
#    1760 if experiment is None:
#    1761     experiment = _EXPERIMENT_CLASS()
# -> 1763 return experiment.predict_model(
#    1764     estimator=estimator,
#    1765     data=data,
#    1766     drift_report=drift_report,
#    1767     round=round,
#    1768     verbose=verbose,
#    1769 )
#
# File c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\pycaret\regression\oop.py:1532, in RegressionExperiment.predict_model(self, estimator, data, drift_report, round, verbose)
#    1476 def predict_model(
#    1477     self,
#    1478     estimator,
#    (...)
#    1482     verbose: bool = True,
#    1483 ) -> pd.DataFrame:
#    1485     """
#    1486     This function predicts ``Label`` using a trained model. When ``data`` is
#    1487     None, it predicts label on the holdout set.
#    (...)
#    1529
#    1530     """
# -> 1532     return super().predict_model(
#    1533         estimator=estimator,
#    1534         data=data,
#    1535         probability_threshold=None,
#    1536         encoded_labels=False,
#    1537         drift_report=drift_report,
#    1538         round=round,
#    1539         verbose=verbose,
#    1540     )
#
# File c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4685, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, drift_report, round, verbose, ml_usecase, display)
#    4683     X_test_, y_test_ = self.X_test_transformed, self.y_test_transformed
#    4684 else:
# -> 4685     data = to_df(data[self.X.columns])  # Ignore all column but the originals
#    4686     X_test_ = self.pipeline.transform(data)
#    4688 # generate drift report
#
# File c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File c:\Users\alyss\anaconda3\envs\pycaret\lib\site-packages\pandas\core\indexes\base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['adjHigh', 'adjLow', 'adjOpen'] not in index"

# %%
concat_df = pd.concat([predictions, predictions_future], axis=0)

# Set the index of concat_df to the date column
concat_df.set_index('date', inplace=True)

# Plot the data
fig = px.line(concat_df, x=concat_df.index, y=["close", "prediction_label"], template='plotly_dark')
fig.show()
